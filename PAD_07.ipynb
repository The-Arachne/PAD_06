# %% [markdown]
# # ZADANIE 1

# %%
import pandas as pd

data = pd.read_csv("wyniki.csv")
data.head
# Out:
# <bound method NDFrame.head of     plec  ocena_koncowa
# 0      F              6
# 1      F              6
# 2      F             10
# 3      F             15
# 4      F             10
# ..   ...            ...
# 352    M              9
# 353    M             16
# 354    M              7
# 355    M             10
# 356    M              9
#
# [357 rows x 2 columns]>

# %%
Fdata = data[data['plec'] == 'F']
Mdata = data[data['plec'] == 'M']

Mdata.head
# Out:
# <bound method NDFrame.head of     plec  ocena_koncowa
# 5      M             15
# 6      M             11
# 8      M             19
# 9      M             15
# 12     M             14
# ..   ...            ...
# 352    M              9
# 353    M             16
# 354    M              7
# 355    M             10
# 356    M              9
#
# [172 rows x 2 columns]>

# %%
import numpy as np

Mresults = Mdata['ocena_koncowa']
M_STD = np.std(Mresults)
M_MEAN = np.mean(Mresults)
M_SHAPE = Mresults.shape[0]

Fresults = Fdata['ocena_koncowa']
F_STD = np.std(Fresults)
F_MEAN = np.mean(Fresults)
F_SHAPE = Fresults.shape[0]


T_STAT = (M_MEAN - F_MEAN)/(np.sqrt(np.square(M_STD)/M_SHAPE + np.square(F_STD)/F_SHAPE))
T_STAT
# Out:
# 1.9440943008790124

# %%
import scipy.stats as stats

df = data.shape[0]-1

p = stats.t.sf(abs(T_STAT), df=df)
p
# Out:
# 0.026335783034178887

# %%
# p value jest mniejsze 0.05 -> hipoteza zerowa do odrzucenia
# hipoteza alternatywna jest prawidłowa

# %% [markdown]
# # ZADANIE 2

# %%
data = pd.read_csv('ZyskiFirmyX.csv')
data.head
# Out:
# <bound method NDFrame.head of       Rok  Zysk
# 0    1821  1645
# 1    1822   658
# 2    1823  1926
# 3    1824   865
# 4    1825   764
# ..    ...   ...
# 195  2016   988
# 196  2017   895
# 197  2018  -178
# 198  2019   543
# 199  2020   316
#
# [200 rows x 2 columns]>

# %%
data['Rok'].describe()
# Out:
# count     200.000000
# mean     1920.500000
# std        57.879185
# min      1821.000000
# 25%      1870.750000
# 50%      1920.500000
# 75%      1970.250000
# max      2020.000000
# Name: Rok, dtype: float64

# %%
import plotly.express as px

px.scatter(data, "Rok", "Zysk")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import statsmodels.formula.api as stsfmapi

model = stsfmapi.ols(formula="Zysk ~ Rok", data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   Zysk   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                   0.09357
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):              0.760
# Time:                        15:29:47   Log-Likelihood:                -1521.3
# No. Observations:                 200   AIC:                             3047.
# Df Residuals:                     198   BIC:                             3053.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1373.8795   1150.888      1.194      0.234    -895.692    3643.452
# ...

# %%
import plotly.graph_objects as go

data["Fit"] = model.fittedvalues

fig = go.Figure()

fig.add_trace(
    go.Scatter(x=data["Rok"], y=data["Zysk"], name="Rok vs Zysk")
)
fig.add_trace(
    go.Scatter(x=data["Rok"], y=data["Fit"], name="Trend - Lin. Reg.")
)
fig.update_layout(title="Regresja liniowa Zysku na przestrzeni lat", xaxis_title="Rok", yaxis_title="Zysk")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # ZADANIE 3

# %%
data = pd.read_csv('spendingscores.csv')
data.head
# Out:
# <bound method NDFrame.head of      Gender  Age  AnnualIncome  SpendingScore
# 0      Male   19            15             39
# 1      Male   21            15             81
# 2    Female   20            16              6
# 3    Female   23            16             77
# 4    Female   31            17             40
# ..      ...  ...           ...            ...
# 195  Female   35           120             79
# 196  Female   45           126             28
# 197    Male   32           126             74
# 198    Male   32           137             18
# 199    Male   30           137             83
#
# [200 rows x 4 columns]>

# %%
data.isna().any()
# Out:
# Gender           False
# Age              False
# AnnualIncome     False
# SpendingScore    False
# dtype: bool

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Gender'].replace(['Male', 'Female'], [1, 0], inplace=True)

data.head
# Out:
# <bound method NDFrame.head of      Gender  Age  AnnualIncome  SpendingScore
# 0         1   19            15             39
# 1         1   21            15             81
# 2         0   20            16              6
# 3         0   23            16             77
# 4         0   31            17             40
# ..      ...  ...           ...            ...
# 195       0   35           120             79
# 196       0   45           126             28
# 197       1   32           126             74
# 198       1   32           137             18
# 199       1   30           137             83
#
# [200 rows x 4 columns]>

# %%
model = stsfmapi.ols("SpendingScore ~ Gender + Age + AnnualIncome", data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          SpendingScore   R-squared:                       0.109
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     7.960
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           4.91e-05
# Time:                        15:29:47   Log-Likelihood:                -922.05
# No. Observations:                 200   AIC:                             1852.
# Df Residuals:                     196   BIC:                             1865.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       73.9300      6.642     11.130      0.000      60.831      87.029
# ...

# %%
fig = px.imshow(data.corr())
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#BEZ -> GENDER
model = stsfmapi.ols("SpendingScore ~ Age + AnnualIncome", data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          SpendingScore   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     11.82
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           1.42e-05
# Time:                        15:29:47   Log-Likelihood:                -922.21
# No. Observations:                 200   AIC:                             1850.
# Df Residuals:                     197   BIC:                             1860.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       73.3479      6.553     11.193      0.000      60.425      86.271
# ...

# %%
#BEZ -> AGE
model = stsfmapi.ols("SpendingScore ~ Gender + AnnualIncome", data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          SpendingScore   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.3510
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):              0.704
# Time:                        15:29:47   Log-Likelihood:                -933.19
# No. Observations:                 200   AIC:                             1872.
# Df Residuals:                     197   BIC:                             1882.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       50.7565      4.818     10.535      0.000      41.255      60.258
# ...

# %%
#BEZ -> INCOME
model = stsfmapi.ols("SpendingScore ~ Gender + Age", data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          SpendingScore   R-squared:                       0.109
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     11.99
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           1.22e-05
# Time:                        15:29:47   Log-Likelihood:                -922.05
# No. Observations:                 200   AIC:                             1850.
# Df Residuals:                     197   BIC:                             1860.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     74.4089      5.281     14.089      0.000      63.994      84.824
# ...

# %%
# NAJWIEKSZE R-SQUARED DLA OSTATNIEGO (bez income) MODELU
